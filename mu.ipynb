# %%
import numpy as np
import pandas as pd
data=pd.read_csv('online_shoppers_intention.csv')
#print(data.head())
data.shape
#print(data[0:3])
#print(data.loc[1:3,['index']])
x=np.array(data.loc[1:20,['ProductRelated']])
t=np.array(data.loc[1:20,['OperatingSystems']])
w=np.array(data.loc[1:20,['ExitRates']])

#print(data['index'])
print(x)
print(w)
#w =np.array(data.loc[1:3,['weights']])
lrate= 0.6
e=1
D=[0,0]
print('learning rate of this epoch is',lrate);
while(e<=20):
    print('Epoch is',e);
    
    for i in range(2):
        for j in range(1):
             temp=0
             for k in range(1):
                temp = temp + ((w[k,j]-x[i,k])**2)
             D[j]=temp
        
        if(D[0]<D[1]):
            J=0
            
        else:
            J=1
            
        
        #print('winning unit is',J+1)
        #print('weight updation ...')
        if J==t[i]:
            for m in range(0):
            
                 w[m,J]=w[m,J] + (lrate *(x[i,m]-w[m,J]))
                 print(w[m,J])
        else:
            for m in range(0):
                w[m,J]=w[m,J] - (lrate *(x[i,m]-w[m,J]))
        
       
        #print('Updated weights',w)
        

    e=e+1
    lrate = 0.5*lrate;
    print(' updated learning rate after ',e,' epoch is',lrate)
# Out:
# [[ 2]
#  [ 1]
#  [ 2]
#  [10]
#  [19]
#  [ 1]
#  [ 0]
#  [ 2]
#  [ 3]
#  [ 3]
#  [16]
#  [ 7]
#  [ 6]
#  [ 2]
#  [23]
#  [ 1]
#  [13]
#  [ 2]
#  [20]
#  [ 8]]
# [[0.1       ]
#  [0.2       ]
#  [0.14      ]
#  [0.05      ]
#  [0.0245614 ]
#  [0.2       ]
#  [0.2       ]
#  [0.1       ]
#  [0.02222222]
#  [0.06666667]
#  [0.02583333]
#  [0.02857143]
#  [0.06666667]
#  [0.1       ]
#  [0.01631264]
#  [0.2       ]
#  [0.00769231]
#  [0.1       ]
#  [0.01      ]
#  [0.00833333]]
# learning rate of this epoch is 0.6
# Epoch is 1
#  updated learning rate after  2  epoch is 0.3
# Epoch is 2
#  updated learning rate after  3  epoch is 0.15
# Epoch is 3
#  updated learning rate after  4  epoch is 0.075
# Epoch is 4
#  updated learning rate after  5  epoch is 0.0375
# Epoch is 5
#  updated learning rate after  6  epoch is 0.01875
# Epoch is 6
#  updated learning rate after  7  epoch is 0.009375
# Epoch is 7
#  updated learning rate after  8  epoch is 0.0046875
# Epoch is 8
#  updated learning rate after  9  epoch is 0.00234375
# Epoch is 9
#  updated learning rate after  10  epoch is 0.001171875
# Epoch is 10
#  updated learning rate after  11  epoch is 0.0005859375
# Epoch is 11
#  updated learning rate after  12  epoch is 0.00029296875
# Epoch is 12
#  updated learning rate after  13  epoch is 0.000146484375
# Epoch is 13
#  updated learning rate after  14  epoch is 7.32421875e-05
# Epoch is 14
#  updated learning rate after  15  epoch is 3.662109375e-05
# Epoch is 15
#  updated learning rate after  16  epoch is 1.8310546875e-05
# Epoch is 16
#  updated learning rate after  17  epoch is 9.1552734375e-06
# Epoch is 17
#  updated learning rate after  18  epoch is 4.57763671875e-06
# Epoch is 18
#  updated learning rate after  19  epoch is 2.288818359375e-06
# Epoch is 19
#  updated learning rate after  20  epoch is 1.1444091796875e-06
# Epoch is 20
#  updated learning rate after  21  epoch is 5.7220458984375e-07
